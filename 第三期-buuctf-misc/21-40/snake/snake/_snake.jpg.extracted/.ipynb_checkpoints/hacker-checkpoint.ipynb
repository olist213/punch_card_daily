# %%
from Crypto.Cipher import AES

key = b'V2hhdCBpcyBOaWNraSBNaW5haidzIGZhdm9yaXRlIHNvbmcgdGhhdCByZWZlcnMgdG8gc25ha2VzPwo='

cipher = AES.new(key, AES.MODE_EAX)

with open("./cipher") as f:
    ss = f.readlines()
    print(ss)

#plaintext = cipher.decrypt(cipher)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-9e8b19e0cecc> in <module>
#       3 key = b'V2hhdCBpcyBOaWNraSBNaW5haidzIGZhdm9yaXRlIHNvbmcgdGhhdCByZWZlcnMgdG8gc25ha2VzPwo='
#       4
# ----> 5 cipher = AES.new(key, AES.MODE_EAX)
#       6
#       7 with open("./cipher") as f:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/Crypto/Cipher/AES.py in new(key, mode, *args, **kwargs)
#     230
#     231     kwargs["add_aes_modes"] = True
# --> 232     return _create_cipher(sys.modules[__name__], key, mode, *args, **kwargs)
#     233
#     234
#
# ~/opt/anaconda3/lib/python3.8/site-packages/Crypto/Cipher/__init__.py in _create_cipher(factory, key, mode, *args, **kwargs)
#      77             raise TypeError("IV is not meaningful for the ECB mode")
#      78
# ---> 79     return modes[mode](factory, **kwargs)
#
# ...
